# %%
import chess
import chess.pgn
import chess.engine
import random
import time
from math import log,sqrt,e,inf

class node:
    def __init__(self,*board):
        if(len(board)>0):
            self.state = board
        else:
            self.state = chess.Board()
        self.action = ''
        self.children = set()
        self.parent = None
        self.N = 0
        self.n = 0
        self.v = 0

def ucb1(curr_node):
    ans = curr_node.v+2*(sqrt(log(curr_node.N+e+(10**-6))/(curr_node.n+(10**-10))))
    return ans

def rollout(board,curr_node):
    
    if(curr_node.state.is_game_over()):
        board1 = curr_node.state
        if(board1.result()=='1-0'):
            #print("h1")
            return (1,curr_node)
        elif(board1.result()=='0-1'):
            #print("h2")
            return (-1,curr_node)
        else:
            return (0.5,curr_node)
    
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node(board)
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
    rnd_state = random.choice(list(curr_node.children))

    return rollout(board,rnd_state)

def expand(curr_node,white):
    if(len(curr_node.children)==0):
        return curr_node
    max_ucb = -inf
    if(white):
        idx = -1
        max_ucb = -inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp>max_ucb):
                idx = i
                max_ucb = tmp
                sel_child = i

        return(expand(sel_child,0))

    else:
        idx = -1
        min_ucb = inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp<min_ucb):
                idx = i
                min_ucb = tmp
                sel_child = i

        return expand(sel_child,1)

def rollback(curr_node,reward):
    curr_node.n+=1
    curr_node.v+=reward
    while(curr_node.parent!=None):
        curr_node.N+=1
        curr_node = curr_node.parent
    return curr_node

def mcts_pred(board,curr_node,over,white,choice,iterations=10):
    if(over):
        return -1
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    map_state_move = dict()
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node(board)
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
        map_state_move[child] = i
        
    while(iterations>0):
        if(white):
            idx = -1
            max_ucb = -inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp>max_ucb):
                    idx = i
                    max_ucb = tmp
                    sel_child = i
            ex_child = expand(sel_child,0)
            reward,state = rollout(board,ex_child)
            curr_node = rollback(state,reward)
            iterations-=1
        elif(choice==1):
            idx = -1
            min_ucb = inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp<min_ucb):
                    idx = i
                    min_ucb = tmp
                    sel_child = i

            ex_child = expand(sel_child,1)

            reward,state = rollout(board,ex_child)

            curr_node = rollback(state,reward)
            iterations-=1
    if(white):
        
        mx = -inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp>mx):
                mx = tmp
                selected_move = map_state_move[i]
        return selected_move
    elif(choice==1):
        mn = inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp<mn):
                mn = tmp
                selected_move = map_state_move[i]
        return selected_move

#to randomize the starting position we can customize the board. for now I am using a random board setup
#board = chess.Board("r1bqkb1r/pppp1Qpp/2n2n2/4p3/2B1P3/8/PPPP1PPP/RNB1K1NR b KQkq - 0 4")

#to let the pc choose random positions
board = chess.Board.from_chess960_pos(random.randint(0, 959))
#board = chess.Board()
print(board)
choice=int(input("Do you want 1. AI vs AI game or 2.Human vs AI game? write 1 or 2"))
if(choice==2):
    white=int(input("Do you want to play as 0.First player or 1.Second player? write 0 or 1"))
else:
    white = 1
moves = 0
pgn = []
game = chess.pgn.Game()
evaluations = []
sm = 0
j=1



while((not board.is_game_over())):
    all_moves = [board.san(i) for i in list(board.legal_moves)]
    start = time.time()
    if(white==1 or choice==1):
        root = node()
        root.state = board
        result = mcts_pred(board,root,board.is_game_over(),white,choice)
        print("time taken to iteration",j,(time.time()-start))
    elif(choice==2):
        print("input format should be something like a2, b6, g3, first one is row, second one is colum")
        print("column is a to h if you are second player, otherwise A to H will be your column and row is from 8 to 1 (up to down)")
        to=input("Write where you want to go")
        frm = input("write from where you want to move")
        result=frm+to
    try:
        board.push_san(result)
    except:
        print(result)
        print("invalid move. game over")
        break
    #print(result)
    pgn.append(result)
    white ^= 1
    j+=1
    
    moves+=1
    print(board)
    print("-----------move done-----------")
#print(board)
print(" ".join(pgn))
print()
#print(evaluations)
print(board.result())
game.headers["Result"] = board.result()
# Out:
# r n q k n b b r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N Q K N B B R
# Do you want 1. AI-AI game or 2.Human-AI game? write 1 or 21
# time taken to iteration 1 4.82654595375061
# r n q k n b b r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . N . . . .
# P P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 2 5.0598461627960205
# r n q k n b b r
# p p p p p . p p
# . . . . . . . .
# . . . . . p . .
# . . . . . . . .
# . . . N . . . .
# P P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 3 5.964323997497559
# r n q k n b b r
# p p p p p . p p
# . . . . . . . .
# . . . . . p . .
# P . . . . . . .
# . . . N . . . .
# . P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 4 5.056308031082153
# r n q k n b b r
# . p p p p . p p
# p . . . . . . .
# . . . . . p . .
# P . . . . . . .
# . . . N . . . .
# . P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 5 4.473997116088867
# r n q k n b b r
# . p p p p . p p
# p . . . . . . .
# . . . . . p . .
# P N . . . . . .
# . . . . . . . .
# . P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 6 4.661262035369873
# r n q k n b . r
# . p p p p . p p
# p . . . . . . .
# . . . . . p . .
# P N . . . . . .
# . b . . . . . .
# . P P P P P P P
# R N Q K . B B R
# -----------move done-----------
# time taken to iteration 7 4.665609121322632
# r n q k n b . r
# . p p p p . p p
# p . . . . . . .
# . . . . . p . .
# P N . . . . . .
# . b N . . . . .
# . P P P P P P P
# R . Q K . B B R
# -----------move done-----------
# time taken to iteration 8 5.624723196029663
# r n q k n b . r
# . p p p p . p .
# p . . . . . . p
# . . . . . p . .
# P N . . . . . .
# . b N . . . . .
# . P P P P P P P
# R . Q K . B B R
# -----------move done-----------
# time taken to iteration 9 4.560496807098389
# r n q k n b . r
# . p p p p . p .
# p . N . . . . p
# . . . . . p . .
# P . . . . . . .
# . b N . . . . .
# . P P P P P P P
# R . Q K . B B R
# -----------move done-----------
# time taken to iteration 10 4.97370171546936
# r . q k n b . r
# . p p p p . p .
# p . n . . . . p
# . . . . . p . .
# P . . . . . . .
# . b N . . . . .
# . P P P P P P P
# R . Q K . B B R
# -----------move done-----------
# time taken to iteration 11 5.066057920455933
# r . q k n b . r
# . p p p p . p .
# p . n . . . . p
# . . . . . p . .
# P . . . . . . .
# . b N . . . . .
# . P P P P P P P
# . R Q K . B B R
# -----------move done-----------
# time taken to iteration 12 5.053477764129639
# r . q k n b . r
# . p p . p . p .
# p . n p . . . p
# . . . . . p . .
# P . . . . . . .
# . b N . . . . .
# . P P P P P P P
# . R Q K . B B R
# -----------move done-----------
# time taken to iteration 13 5.198574781417847
# r . q k n b . r
# . p p . p . p .
# p . n p . . . p
# . . . N . p . .
# P . . . . . . .
# . b . . . . . .
# . P P P P P P P
# . R Q K . B B R
# -----------move done-----------
# time taken to iteration 14 4.424095153808594
# r q . k n b . r
# . p p . p . p .
# p . n p . . . p
# . . . N . p . .
# P . . . . . . .
# . b . . . . . .
# . P P P P P P P
# . R Q K . B B R
# -----------move done-----------
# time taken to iteration 15 4.8074951171875
# r q . k n b . r
# . p p . p . p .
# p . n p . . . p
# . . . N . p . .
# P . . . . . . .
# . b . . . . . .
# . P P P P P P P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 16 5.339457988739014
# r q . k n b . r
# . . p . p . p .
# p p n p . . . p
# . . . N . p . .
# P . . . . . . .
# . b . . . . . .
# . P P P P P P P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 17 4.718648672103882
# r q . k n b . r
# . . p . p . p .
# p p n p . . . p
# . . . . . p . .
# P . . . . . . .
# . b . . N . . .
# . P P P P P P P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 18 4.541305065155029
# r q . k n b . r
# . . p . p . p .
# . p n p . . . p
# p . . . . p . .
# P . . . . . . .
# . b . . N . . .
# . P P P P P P P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 19 3.979559898376465
# r q . k n b . r
# . . p . p . p .
# . p n p . . . p
# p . . . . p . .
# P . . . . . P .
# . b . . N . . .
# . P P P P P . P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 20 5.125030279159546
# r q . k n b . .
# . . p . p . p r
# . p n p . . . p
# p . . . . p . .
# P . . . . . P .
# . b . . N . . .
# . P P P P P . P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 21 4.017898082733154
# r q . k n b . .
# . . p . p . p r
# . p n p . . . p
# p . . . . p . .
# P . . . . . P .
# . P . . N . . .
# . P . P P P . P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 22 3.9539501667022705
# r q . k n b . .
# . . p . p . p r
# . p n p . . . p
# p . . . . . . .
# P . . . . p P .
# . P . . N . . .
# . P . P P P . P
# . R Q . K B B R
# -----------move done-----------
# time taken to iteration 23 4.2982542514801025
# r q . k n b . .
# . . p . p . p r
# . p n p . . . p
# p . . . . . . .
# P . . . . p P .
# . P . . N . . .
# . P . P P P B P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 24 4.280045032501221
# r q . k n b . .
# . . p . p . p r
# . p . p . . . p
# p . . . . . . .
# P n . . . p P .
# . P . . N . . .
# . P . P P P B P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 25 4.391808986663818
# B q . k n b . .
# . . p . p . p r
# . p . p . . . p
# p . . . . . . .
# P n . . . p P .
# . P . . N . . .
# . P . P P P . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 26 4.14876389503479
# B q . k n b . .
# . . p . p . . r
# . p . p . . p p
# p . . . . . . .
# P n . . . p P .
# . P . . N . . .
# . P . P P P . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 27 4.313310146331787
# B q . k n b . .
# . . p . p . . r
# . p . p . . p p
# p . . . . N . .
# P n . . . p P .
# . P . . . . . .
# . P . P P P . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 28 4.056890249252319
# B q . k n b . .
# . . p . . . . r
# . p . p . . p p
# p . . . p N . .
# P n . . . p P .
# . P . . . . . .
# . P . P P P . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 29 3.4869210720062256
# B q . k n b . .
# . . p . . . . r
# . p . p . . p p
# p . . . p N . .
# P n . . . p P .
# . P . . . P . .
# . P . P P . . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 30 3.892040967941284
# B q . k n b . .
# . . p . . . . r
# . p . p . . p p
# p . . . . N . .
# P n . . p p P .
# . P . . . P . .
# . P . P P . . P
# . R Q . K . B R
# -----------move done-----------
# time taken to iteration 31 3.5155210494995117
# B q . k n b . .
# . . p . . . . r
# . p . p . . p p
# p . . . . N . .
# P n . . p p P .
# . P . . . P . .
# . P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 32 4.192946910858154
# B q . k n b . .
# . . p . . . . r
# . . . p . . p p
# p p . . . N . .
# P n . . p p P .
# . P . . . P . .
# . P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 33 3.6231679916381836
# B q . k n b . .
# . . p . . . . r
# . . . N . . p p
# p p . . . . . .
# P n . . p p P .
# . P . . . P . .
# . P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 34 3.2132883071899414
# B q . k n b . .
# . . p . . . . r
# . . . N . . p p
# p p . . . . . .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 35 3.9991250038146973
# . q . k n b . .
# . . p . . . . r
# . . . N . . p p
# p p . B . . . .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 36 3.634085178375244
# . q . k n b . .
# . . p . . . . r
# . . . N . . . p
# p p . B . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 37 3.855926990509033
# . q . k n b B .
# . . p . . . . r
# . . . N . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 38 4.1866679191589355
# . q . k . b B .
# . . p . . . . r
# . . . n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . R . Q K . B R
# -----------move done-----------
# time taken to iteration 39 4.142777919769287
# . q . k . b B .
# . . p . . . . r
# . . . n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . . R Q K . B R
# -----------move done-----------
# time taken to iteration 40 3.5981509685516357
# . q . k . b B .
# . . . . . . . r
# . . p n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . . R Q K . B R
# -----------move done-----------
# time taken to iteration 41 3.5725769996643066
# . q . k . b B .
# . . . . . . . r
# . . p n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P R P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 42 3.612794876098633
# . q . . . b B .
# . . . k . . . r
# . . p n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P R P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 43 3.4943671226501465
# . q . . . b B .
# . . . k . . . r
# . . R n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 44 3.9127979278564453
# . q . . . . B .
# . . . k b . . r
# . . R n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 45 3.2251577377319336
# . q . . . . . .
# . . . k b B . r
# . . R n . . . p
# p p . . . . p .
# P . . . p p P .
# . P . . . P . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 46 4.024871349334717
# . q . . . . . .
# . . . k b B . r
# . . R n . . . p
# p p . . . . p .
# P . . . . p P .
# . P . . . p . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 47 3.1112000942230225
# . q . . . . . .
# . . . k b B . r
# . . . R . . . p
# p p . . . . p .
# P . . . . p P .
# . P . . . p . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 48 2.614321231842041
# . q . . . . . .
# . . k . b B . r
# . . . R . . . p
# p p . . . . p .
# P . . . . p P .
# . P . . . p . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 49 2.99615478515625
# . q . . . . . .
# . . k R b B . r
# . . . . . . . p
# p p . . . . p .
# P . . . . p P .
# . P . . . p . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 50 2.73457407951355
# . q . . . . . .
# . . . k b B . r
# . . . . . . . p
# p p . . . . p .
# P . . . . p P .
# . P . . . p . .
# n P . P P . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 51 3.5053329467773438
# . q . . . . . .
# . . . k b B . r
# . . . . . . . p
# p p . . . . p .
# P . . . P p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 52 3.4857921600341797
# . q . . . . . .
# . . . . b B . r
# . . k . . . . p
# p p . . . . p .
# P . . . P p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 53 3.2663040161132812
# . q . . . . . .
# . . . . b B . r
# . . k . . . . p
# p p . . P . p .
# P . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 54 3.58964204788208
# . q . . . . . .
# . k . . b B . r
# . . . . . . . p
# p p . . P . p .
# P . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q K . B R
# -----------move done-----------
# time taken to iteration 55 3.7029428482055664
# . q . . . . . .
# . k . . b B . r
# . . . . . . . p
# p p . . P . p .
# P . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 56 2.5052528381347656
# . q . . . . . .
# . k . . b B . r
# . . . . . . . p
# p . . . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 57 2.980236053466797
# . q . . . . . .
# . k . . b . . r
# . . . . . . . p
# p . . . P . p .
# p . B . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 58 2.822631359100342
# . q . . . . . .
# . k . . . . . r
# . . . . . . . p
# p . b . P . p .
# p . B . . p P .
# . P . . . p . .
# n P . P . . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 59 2.563664197921753
# . q . . . . . .
# . k . . . . . r
# . . . . . . . p
# p . b . P . p .
# p . B . . p P .
# . P . . . p . .
# n P Q P . . . P
# . . . . . K B R
# -----------move done-----------
# time taken to iteration 60 3.107211112976074
# . q . . . . . .
# . k . . r . . .
# . . . . . . . p
# p . b . P . p .
# p . B . . p P .
# . P . . . p . .
# n P Q P . . . P
# . . . . . K B R
# -----------move done-----------
# time taken to iteration 61 2.5863089561462402
# . q . . . . . .
# . k . . r . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P Q P B . . P
# . . . . . K B R
# -----------move done-----------
# time taken to iteration 62 3.091784954071045
# . . . . . . . q
# . k . . r . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P Q P B . . P
# . . . . . K B R
# -----------move done-----------
# time taken to iteration 63 2.8491268157958984
# . . . . . . . q
# . k . . r . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P B . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 64 3.2234268188476562
# . . . . . . . q
# . k . r . . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P B . . P
# . . . Q . K B R
# -----------move done-----------
# time taken to iteration 65 2.36942982673645
# . . . . . . . q
# . k . r . . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P B . . P
# . Q . . . K B R
# -----------move done-----------
# time taken to iteration 66 3.0111570358276367
# . . . . q . . .
# . k . r . . . .
# . . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P B . . P
# . Q . . . K B R
# -----------move done-----------
# time taken to iteration 67 3.373342990875244
# . . . . q . . .
# . k . r . . . .
# B . . . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . Q . . . K B R
# -----------move done-----------
# time taken to iteration 68 3.046574115753174
# . . . . q . . .
# . . . r . . . .
# B . k . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . Q . . . K B R
# -----------move done-----------
# time taken to iteration 69 2.714089870452881
# . . . . q . . .
# . . . r . . . .
# B . k . . . . p
# p . b . P . p .
# p . . . . p P .
# . P . . . p . .
# n P . P . . . P
# . Q . . K . B R
# -----------move done-----------
# time taken to iteration 70 2.3390002250671387
# . . . . q . . .
# . . . r . . . .
# B . k . . . . p
# p . b . P . p .
# p . . . . p P .
# . P n . . p . .
# . P . P . . . P
# . Q . . K . B R
# -----------move done-----------
# time taken to iteration 71 3.19284725189209
# . . . . q . . .
# . . . r . . . .
# B . k . . . . p
# p . b . P . p .
# p . . . . p P .
# . P n . B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 72 2.393746852874756
# . . . . q b . .
# . . . r . . . .
# B . k . . . . p
# p . . . P . p .
# p . . . . p P .
# . P n . B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 73 2.9729321002960205
# . . . . q b . .
# . . . r . . . .
# . . k . . . . p
# p . . . P . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 74 3.526787757873535
# . . . . q b . .
# r . . . . . . .
# . . k . . . . p
# p . . . P . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 75 2.733794927597046
# . . . . q b . .
# r . . . . . . .
# . . k . P . . p
# p . . . . . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 76 2.994533061981201
# . . . . q b . .
# . . . r . . . .
# . . k . P . . p
# p . . . . . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . Q . . K . . R
# -----------move done-----------
# time taken to iteration 77 3.4202449321746826
# . . . . q b . .
# . . . r . . . .
# . . k . P . . p
# p . . . . . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 78 3.294457197189331
# . . . . . b . .
# . . . r . q . .
# . . k . P . . p
# p . . . . . p .
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 79 3.0288326740264893
# . . . . . b . .
# . . . r . q . .
# . . k . P . . p
# p . . . . . p .
# p . . . . p P .
# . P n B . p . .
# . P . P . B . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 80 3.1756908893585205
# . . . . . b . .
# . . . r . q . .
# . . k . P . . .
# p . . . . . p p
# p . . . . p P .
# . P n B . p . .
# . P . P . B . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 81 3.044677972793579
# . . . . . b . .
# . . . r . q . .
# . . k . P . . .
# p . . . . . p p
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 82 3.338905096054077
# . . . . . b . .
# . . . r . . . .
# . . k . P . . .
# p . . . . q p p
# p . . . . p P .
# . P n B B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 83 2.997170925140381
# . . . . . b . .
# . . . r . . . .
# B . k . P . . .
# p . . . . q p p
# p . . . . p P .
# . P n . B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 84 3.150178909301758
# . . . . . b . .
# . . . r . . . .
# B . k . P . . .
# p . . n . q p p
# p . . . . p P .
# . P . . B p . .
# . P . P . . . P
# . . . Q K . . R
# -----------move done-----------
# time taken to iteration 85 3.121074914932251
# . . . . . b . .
# . . . r . . . .
# . . k . P . . .
# p . . n . q p p
# p . . . . p P .
# . P . . B p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 86 2.627228021621704
# . . . . . b . .
# . . . r . . . .
# . . k . P . . .
# p . . n . . p p
# p . . . . p q .
# . P . . B p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 87 2.9275801181793213
# . . . . . b . .
# B . . r . . . .
# . . k . P . . .
# p . . n . . p p
# p . . . . p q .
# . P . . . p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 88 3.0091469287872314
# . . . . . b . .
# r . . . . . . .
# . . k . P . . .
# p . . n . . p p
# p . . . . p q .
# . P . . . p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 89 1.3361117839813232
# . . . . . b . .
# r . . . P . . .
# . . k . . . . .
# p . . n . . p p
# p . . . . p q .
# . P . . . p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 90 2.651766061782837
# . . . . . b . .
# r . . . P . . .
# . . . . . . . .
# p . k n . . p p
# p . . . . p q .
# . P . . . p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 91 1.9043707847595215
# . . . . . R . .
# r . . . . . . .
# . . . . . . . .
# p . k n . . p p
# p . . . . p q .
# . P . . . p . .
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 92 2.1594350337982178
# . . . . . R . .
# r . . . . . . .
# . . . . . . . .
# p . k n . . p p
# p . . . . p . .
# . P . . . p . q
# . P . P . . . P
# . . . Q K B . R
# -----------move done-----------
# time taken to iteration 93 3.0671932697296143
# . . . . . R . .
# r . . . . . . .
# . . . . . . . .
# p . k n . . p p
# p . . . . p . .
# . P . . . p . q
# . P . P . K . P
# . . . Q . B . R
# -----------move done-----------
# time taken to iteration 94 2.4320688247680664
# . . . . . R . .
# r . . . . . . .
# . . . . . . . .
# p . k n . . p p
# . . . . . p . .
# p P . . . p . q
# . P . P . K . P
# . . . Q . B . R
# -----------move done-----------
# time taken to iteration 95 2.270362138748169
# . . . . . R . .
# r . . . . . . .
# . . . . . . . .
# p . k n . . p p
# . . . . . p . .
# p P . . . p . q
# . P . P . K . P
# . Q . . . B . R
# -----------move done-----------
# time taken to iteration 96 2.2348790168762207
# . . . . . R . .
# . . . r . . . .
# . . . . . . . .
# p . k n . . p p
# . . . . . p . .
# p P . . . p . q
# . P . P . K . P
# . Q . . . B . R
# -----------move done-----------
# time taken to iteration 97 1.961961030960083
# . . . . . R . .
# . . . r . . . .
# B . . . . . . .
# p . k n . . p p
# . . . . . p . .
# p P . . . p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 98 1.9207453727722168
# . . . . . R . .
# . . . r . . . .
# B . . . . . . .
# p . k . . . p p
# . . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 99 2.437441825866699
# . . R . . . . .
# . . . r . . . .
# B . . . . . . .
# p . k . . . p p
# . . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 100 1.4829769134521484
# . . R . . . . .
# . . r . . . . .
# B . . . . . . .
# p . k . . . p p
# . . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 101 2.4347681999206543
# . R . . . . . .
# . . r . . . . .
# B . . . . . . .
# p . k . . . p p
# . . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 102 2.302125930786133
# . R . . . . . .
# . . r . . . . .
# B . . . . . . .
# . . k . . . p p
# p . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 103 2.7490479946136475
# . . . . . . R .
# . . r . . . . .
# B . . . . . . .
# . . k . . . p p
# p . . . . p . .
# p P . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 104 2.8950788974761963
# . . . . . . R .
# . . r . . . . .
# B . . . . . . .
# . . k . . . p p
# . . . . . p . .
# p p . . n p . q
# . P . P . K . P
# . Q . . . . . R
# -----------move done-----------
# time taken to iteration 105 1.961993932723999
# . . . . . . R .
# . . r . . . . .
# B . . . . . Q .
# . . k . . . p p
# . . . . . p . .
# p p . . n p . q
# . P . P . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 106 2.7943010330200195
# . . . . . . R .
# . . r . . . . .
# B . . . q . Q .
# . . k . . . p p
# . . . . . p . .
# p p . . n p . .
# . P . P . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 107 2.4692893028259277
# . . B . . . R .
# . . r . . . . .
# . . . . q . Q .
# . . k . . . p p
# . . . . . p . .
# p p . . n p . .
# . P . P . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 108 3.085573196411133
# . . B . . . R .
# . . r . . . . .
# . . . . . . Q .
# . . k . . . p p
# . . . . . p . .
# p p . . n p . q
# . P . P . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 109 2.1802978515625
# . . B . . . R .
# . . r . . . . .
# . . . . . . Q .
# . . k . . . p p
# . . . P . p . .
# p p . . n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 110 2.3222639560699463
# . . B . . . R .
# . . r . . . . .
# . . . . . . Q .
# . . . . . . p p
# . . k P . p . .
# p p . . n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 111 1.9706218242645264
# . . B . . . R .
# . . r . . . . .
# . . . . . . . .
# . . . . . . p p
# . . k P . p . .
# p p . Q n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 112 1.8451290130615234
# . . B . . . R .
# . . r . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# p p . Q n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 113 2.4996590614318848
# . . B . . . R .
# . . r . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# p p Q . n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 114 2.5424978733062744
# . . B . . . R .
# r . . . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# p p Q . n p . q
# . P . . . K . P
# . . . . . . . R
# -----------move done-----------
# time taken to iteration 115 2.236372232437134
# . . B . . . R .
# r . . . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# p p Q . n p . q
# . P . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 116 2.712460994720459
# . . B . . . R .
# r . . . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . q
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 117 1.8027267456054688
# . . B R . . . .
# r . . . . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . q
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 118 1.7346830368041992
# . . B R . . . .
# . . . r . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . q
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 119 1.5237290859222412
# . . . R . . . .
# . . . B . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . q
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 120 1.1791760921478271
# . . . R . . . .
# . . . q . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 121 1.74013090133667
# R . . . . . . .
# . . . q . . . .
# . . . . . . . .
# . . . k . . p p
# . . . P . p . .
# . p Q . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 122 1.5139811038970947
# R . . . . . . .
# . . . q . . . .
# . . . . k . . .
# . . . . . . p p
# . . . P . p . .
# . p Q . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 123 1.7376132011413574
# R . . . . . . .
# . . Q q . . . .
# . . . . k . . .
# . . . . . . p p
# . . . P . p . .
# . p . . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 124 2.2654569149017334
# R . . . . . . .
# . . Q . . . . .
# . . . . k . . .
# . . . . . . p p
# . . . q . p . .
# . p . . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 125 2.1753649711608887
# . . . . . . . .
# . . Q . . . . .
# . . . . k . . .
# . . . . . . p p
# R . . q . p . .
# . p . . n p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 126 2.146531105041504
# . . . . . . . .
# . . Q . . . . .
# . . . . k . . .
# . . . . . . p p
# R . n q . p . .
# . p . . . p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 127 0.5937910079956055
# . . . . . . . .
# . . Q . . . . .
# . . . . k . . .
# . . . . . . p p
# . . n q . p . .
# R p . . . p . .
# . p . . . . . P
# . . . . K . . R
# -----------move done-----------
# time taken to iteration 128 0.002249002456665039
# . . . . . . . .
# . . Q . . . . .
# . . . . k . . .
# . . . . . . p p
# . . n q . p . .
# R p . . . p . .
# . . . . . . . P
# . q . . K . . R
# -----------move done-----------
# Nd3 f5 a4 a6 Nb4 Bb3 Nc3 h6 Nc6+ Nxc6 Rb1 d6 Nd5 Qb8 Ke1 b6 Ne3 a5 g4 Rh7 cxb3 f4 Bg2 Nb4 Bxa8 g6 Nf5 e5 f3 e4 Qd1 b5 Nxd6 Na2 Bd5 g5 Bg8 Nxd6 Rc1 c6 Rc2 Kd7 Rxc6 Be7 Bf7 exf3 Rxd6+ Kc7 Rd7+ Kxd7 e4 Kc6 e5 Kb7 Kf1 bxa4 Bc4 Bc5 Qc2 Re7 Be2 Qh8 Qd1 Rd7 Qb1 Qe8 Ba6+ Kc6 Ke1 Nc3 Be3 Bf8 Bd3 Ra7 e6 Rd7 Qd1 Qf7 Bf2 h5 Be3 Qf5 Ba6 Nd5 Bf1 Qxg4 Ba7 Rxa7 e7 Kc5 exf8=R Qh3 Kf2 a3 Qb1 Rd7 Ba6 Ne3 Rc8+ Rc7 Rb8 a4 Rg8 axb3 Qg6 Qe6 Bc8 Qh3 d4+ Kc4 Qd3+ Kd5 Qc3 Ra7 Ke1 axb2 Rd8+ Rd7 Bxd7 Qxd7 Ra8 Ke6 Qc7 Qxd4 Ra4 Nc4 Ra3 b1=Q#
#
# 0-1
