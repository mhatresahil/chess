# %%
import chess
import chess.pgn
import chess.engine
import random
import time
from math import log,sqrt,e,inf

engine = chess.engine.SimpleEngine.popen_uci("stockfish")
class node():
    def __init__(self):
        self.state = chess.Board()
        self.action = ''
        self.children = set()
        self.parent = None
        self.N = 0
        self.n = 0
        self.v = 0

def ucb1(curr_node):
    ans = curr_node.v+2*(sqrt(log(curr_node.N+e+(10**-6))/(curr_node.n+(10**-10))))
    return ans

def rollout(curr_node):
    
    if(curr_node.state.is_game_over()):
        board = curr_node.state
        if(board.result()=='1-0'):
            #print("h1")
            return (1,curr_node)
        elif(board.result()=='0-1'):
            #print("h2")
            return (-1,curr_node)
        else:
            return (0.5,curr_node)
    
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node()
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
    rnd_state = random.choice(list(curr_node.children))

    return rollout(rnd_state)

def expand(curr_node,white):
    if(len(curr_node.children)==0):
        return curr_node
    max_ucb = -inf
    if(white):
        idx = -1
        max_ucb = -inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp>max_ucb):
                idx = i
                max_ucb = tmp
                sel_child = i

        return(expand(sel_child,0))

    else:
        idx = -1
        min_ucb = inf
        sel_child = None
        for i in curr_node.children:
            tmp = ucb1(i)
            if(tmp<min_ucb):
                idx = i
                min_ucb = tmp
                sel_child = i

        return expand(sel_child,1)

def rollback(curr_node,reward):
    curr_node.n+=1
    curr_node.v+=reward
    while(curr_node.parent!=None):
        curr_node.N+=1
        curr_node = curr_node.parent
    return curr_node

def mcts_pred(curr_node,over,white,iterations=10):
    if(over):
        return -1
    all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
    map_state_move = dict()
    
    for i in all_moves:
        tmp_state = chess.Board(curr_node.state.fen())
        tmp_state.push_san(i)
        child = node()
        child.state = tmp_state
        child.parent = curr_node
        curr_node.children.add(child)
        map_state_move[child] = i
        
    while(iterations>0):
        if(white):
            idx = -1
            max_ucb = -inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp>max_ucb):
                    idx = i
                    max_ucb = tmp
                    sel_child = i
            ex_child = expand(sel_child,0)
            reward,state = rollout(ex_child)
            curr_node = rollback(state,reward)
            iterations-=1
        else:
            idx = -1
            min_ucb = inf
            sel_child = None
            for i in curr_node.children:
                tmp = ucb1(i)
                if(tmp<min_ucb):
                    idx = i
                    min_ucb = tmp
                    sel_child = i

            ex_child = expand(sel_child,1)

            reward,state = rollout(ex_child)

            curr_node = rollback(state,reward)
            iterations-=1
    if(white):
        
        mx = -inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp>mx):
                mx = tmp
                selected_move = map_state_move[i]
        return selected_move
    else:
        mn = inf
        idx = -1
        selected_move = ''
        for i in (curr_node.children):
            tmp = ucb1(i)
            if(tmp<mn):
                mn = tmp
                selected_move = map_state_move[i]
        return selected_move

board = chess.Board()

white = 1
moves = 0
pgn = []
game = chess.pgn.Game()
evaluations = []
sm = 0
cnt = 0
eval =0
while((not board.is_game_over())):
    all_moves = [board.san(i) for i in list(board.legal_moves)]
    #start = time.time()
    root = node()
    root.state = board
    result = mcts_pred(root,board.is_game_over(),white)
    #sm+=(time.time()-start)
    board.push_san(result)
    #print(result)
    pgn.append(result)
    white ^= 1
    #cnt+=1
    
    moves+=1
    info = engine.analyse(board, chess.engine.Limit(depth=24))
    eval += info['score'].white()
    print(board)

print(board)
print(" ".join(pgn))
print()
#print(evaluations)
print(board.result())
print(eval)
game.headers["Result"] = board.result()
# Out:
# -59
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . P
# . . . . . . . .
# P P P P P P P .
# R N B Q K B N R
# -8
# r n b q k b n r
# . p p p p p p p
# p . . . . . . .
# . . . . . . . .
# . . . . . . . P
# . . . . . . . .
# P P P P P P P .
# R N B Q K B N R
# -130
# r n b q k b n r
# . p p p p p p p
# p . . . . . . .
# . . . . . . . .
# . . . . . P . P
# . . . . . . . .
# P P P P P . P .
# R N B Q K B N R
# -12
# r n b q k b n r
# . . p p p p p p
# p p . . . . . .
# . . . . . . . .
# . . . . . P . P
# . . . . . . . .
# P P P P P . P .
# R N B Q K B N R
# -171
# r n b q k b n r
# . . p p p p p p
# p p . . . . . .
# . . . . . . . .
# . . . . . P . P
# . . . . . . . R
# P P P P P . P .
# R N B Q K B N .
# -108
# r n b q k b n r
# . . p . p p p p
# p p . p . . . .
# . . . . . . . .
# . . . . . P . P
# . . . . . . . R
# P P P P P . P .
# R N B Q K B N .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 171
#     169 root = node()
#     170 root.state = board
# --> 171 result = mcts_pred(root,board.is_game_over(),white)
#     172 #sm+=(time.time()-start)
#     173 board.push_san(result)
#
# Cell In[2], line 114, in mcts_pred(curr_node, over, white, iterations)
#     112         sel_child = i
#     113 ex_child = expand(sel_child,0)
# --> 114 reward,state = rollout(ex_child)
#     115 curr_node = rollback(state,reward)
#     116 iterations-=1
#
# Cell In[2], line 47, in rollout(curr_node)
#      44     curr_node.children.add(child)
#      45 rnd_state = random.choice(list(curr_node.children))
# ---> 47 return rollout(rnd_state)
#
# Cell In[2], line 47, in rollout(curr_node)
#      44     curr_node.children.add(child)
#      45 rnd_state = random.choice(list(curr_node.children))
# ---> 47 return rollout(rnd_state)
#
#     [... skipping similar frames: rollout at line 47 (47 times)]
#
# Cell In[2], line 47, in rollout(curr_node)
#      44     curr_node.children.add(child)
#      45 rnd_state = random.choice(list(curr_node.children))
# ---> 47 return rollout(rnd_state)
#
# Cell In[2], line 39, in rollout(curr_node)
#      36 all_moves = [curr_node.state.san(i) for i in list(curr_node.state.legal_moves)]
#      38 for i in all_moves:
# ---> 39     tmp_state = chess.Board(curr_node.state.fen())
#      40     tmp_state.push_san(i)
#      41     child = node()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/chess/__init__.py:1556, in Board.__init__(self, fen, chess960)
#    1554     self.reset()
#    1555 else:
# -> 1556     self.set_fen(fen)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/chess/__init__.py:2494, in Board.set_fen(self, fen)
#    2491     raise ValueError(f"fen string has more parts than expected: {fen!r}")
#    2493 # Validate the board part and set it.
# -> 2494 self._set_board_fen(board_part)
#    2496 # Apply.
#    2497 self.turn = turn
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/chess/__init__.py:989, in BaseBoard._set_board_fen(self, fen)
#     987 if previous_was_digit:
#     988     raise ValueError(f"two subsequent digits in position part of fen: {fen!r}")
# --> 989 field_sum += int(c)
#     990 previous_was_digit = True
#     991 previous_was_piece = False
#
# KeyboardInterrupt:
